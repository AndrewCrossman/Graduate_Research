# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewCrossman/Graduate_Research/blob/main/Peak_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import csv
import glob
import numpy as np
from astropy.coordinates import cartesian_to_spherical
import pandas as pd
import scipy as sp
from scipy.signal import find_peaks
from scipy import optimize
from google.colab import files
import matplotlib.pylab as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !ls '/content/drive/My Drive/BNL_July_2023_XRD/024_xrd/integration'
# Out:
# 02423.opju
# 024_xrd_20230713-094211_8a65e3_primary-1_mean_q.chi
# 024_xrd_20230713-094211_8a65e3_primary-1_mean_tth.chi

# %%
xrd_data = pd.read_csv("/content/drive/My Drive/BNL_July_2023_XRD/024_xrd/integration/024_xrd_20230713-094211_8a65e3_primary-1_mean_q.chi",sep=" ")

# %%
Q_space = np.array(xrd_data.iloc[:,1][500:])
peaks, _ = find_peaks(Q_space, distance=20, width=5, prominence=2)
np.diff(peaks)
plt.plot(Q_space)
plt.plot(peaks, Q_space[peaks], "x")
plt.show()

# %%
XRD_dir = '/content/drive/My Drive/BNL_July_2023_XRD/'
XRD_data_files = glob.glob(XRD_dir + '*26*/integration/*_q.chi')
sort(XRD_data_files)
# Out:
# array(['/content/drive/My Drive/BNL_July_2023_XRD/26J_xrd/integration/26J_xrd_20230713-101109_92adb1_primary-1_mean_q.chi',
#        '/content/drive/My Drive/BNL_July_2023_XRD/26K_xrd/integration/26K_xrd_20230713-100956_587dda_primary-1_mean_q.chi',
#        '/content/drive/My Drive/BNL_July_2023_XRD/26L_xrd/integration/26L_xrd_20230713-101558_3b7ba1_primary-1_mean_q.chi',
#        '/content/drive/My Drive/BNL_July_2023_XRD/26M_xrd/integration/26M_xrd_20230713-101710_ea5b8d_primary-1_mean_q.chi',
#        '/content/drive/My Drive/BNL_July_2023_XRD/26N_xrd/integration/26N_xrd_20230713-101823_c19c6c_primary-1_mean_q.chi',
#        '/content/drive/My Drive/BNL_July_2023_XRD/26O_xrd/integration/26O_xrd_20230713-101935_b9205c_primary-1_mean_q.chi'],
#       dtype='<U113')

# %%
for XRD_file in sort(XRD_data_files):
  print(XRD_file)
  xrd_data = pd.read_csv(XRD_file,sep=" ")
  Intensity = np.array(xrd_data.iloc[:,1][500:])
  Q_space = np.array(xrd_data.iloc[:,0][500:])
  peaks, _ = find_peaks(Intensity, distance=10, width=5, prominence=3)
  #print(np.diff(peaks))
  print(Intensity[peaks])
  print(Q_space[peaks])
  plt.plot(Intensity)
  plt.plot(peaks, Intensity[peaks], "x")
  plt.show()
# Out:
# /content/drive/My Drive/BNL_July_2023_XRD/26J_xrd/integration/26J_xrd_20230713-101109_92adb1_primary-1_mean_q.chi
# [ 20.5475502  149.18347168 125.46502686  54.73847198  45.90576935
#    7.8805337   32.23067474  28.48788071  30.40371895  26.93627739
#   11.89538956  10.54347324  10.22419453  14.96765327   9.31204224
#    7.28885937   7.28823662   8.93100071]
# [ 2.55059568  3.01634964  3.08441044  3.48554812  3.5607488   4.16577448
#   4.92428534  5.03872828  5.77511021  5.91087841  6.03233586  6.17520302
#   7.59518984  7.7840535   7.97285858  8.73813578  9.05816852 10.55603106]
# /content/drive/My Drive/BNL_July_2023_XRD/26K_xrd/integration/26K_xrd_20230713-100956_587dda_primary-1_mean_q.chi
# [ 10.04699326 156.14411926 137.28791809  55.67037582  49.48561859
#   33.55196762  31.58278847  31.50373459  29.9383564   12.55251598
#   11.62572193  10.550313    16.65336037  10.2099762    7.75600147
#    7.58269453   9.02186108]
# ...

# %%
Peak #1     Peak #2
3.01276741  3.08441044 024
3.01276741  3.08441044 24A
3.01276741  3.08082836 24B
3.01993186  3.08441044 24C
3.07366419  3.07366419 24D

3.01634964  3.08441044 26J
3.01634964  3.0879925  26K
3.05217148  3.05217148 26L
3.05217148  3.05217148 26M
3.01212038  3.08732934 26N
3.01276741  3.0879925  26O
