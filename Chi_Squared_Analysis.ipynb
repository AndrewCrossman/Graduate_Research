# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewCrossman/Graduate_Research/blob/main/Chi_Squared_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import requests
import numpy as np
import requests
import io
from astropy.coordinates import cartesian_to_spherical
import pandas as pd
import scipy as sp
from sklearn.neighbors import KDTree
from scipy import optimize
from google.colab import files
import matplotlib.pylab as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url1 = 'https://raw.githubusercontent.com/AndrewCrossman/Graduate_Research/main/Tests/RMC_Coreshell5050_PdNi_onAu_r25_1-10-10_v1/rmc_suite.log'
url2 = 'https://raw.githubusercontent.com/AndrewCrossman/Graduate_Research/main/Tests/RMC_Coreshell5050_PdNi_onAu_r25_1-10-10_v2/rmc_suite.log'
url3 = 'https://raw.githubusercontent.com/AndrewCrossman/Graduate_Research/main/Tests/RMC_Coreshell5050_PdNi_onAu_r25_1-10-10_v3/rmc_suite.log'
url4 = 'https://raw.githubusercontent.com/AndrewCrossman/Graduate_Research/main/Tests/RMC_Coreshell5050_PdNi_onAu_r25_1-10-10_v4/rmc_suite.log'
url5 = 'https://raw.githubusercontent.com/AndrewCrossman/Graduate_Research/main/Tests/RMC_Coreshell5050_PdNi_onAu_r25_1-10-10_v5/rmc_suite.log'
PlotTitle = r'$Pd_{50}/Ni_{50}$ 1-10-10'
savename = 'Pd50Ni50_1-10-10_chi_squared_runs.png'
page1 = requests.get(url1)
page2 = requests.get(url2)
page3 = requests.get(url3)
page4 = requests.get(url4)
page5 = requests.get(url5)

# %%
chi_squared1 = []
log_text1 = page1.text.split()
for i in range(len(log_text1)):
  if log_text1[i]=='s2x2:':
    chi_squared1.append(float(log_text1[i+1]))

chi_squared2 = []
log_text2 = page2.text.split()
for i in range(len(log_text2)):
  if log_text2[i]=='s2x2:':
    chi_squared2.append(float(log_text2[i+1]))

chi_squared3 = []
log_text3 = page3.text.split()
for i in range(len(log_text3)):
  if log_text3[i]=='s2x2:':
    chi_squared3.append(float(log_text3[i+1]))

chi_squared4 = []
log_text4 = page4.text.split()
for i in range(len(log_text4)):
  if log_text4[i]=='s2x2:':
    chi_squared4.append(float(log_text4[i+1]))

chi_squared5 = []
log_text5 = page5.text.split()
for i in range(len(log_text5)):
  if log_text5[i]=='s2x2:':
    chi_squared5.append(float(log_text5[i+1]))
# Out:
# "\nchi_squared3 = []\nlog_text3 = page3.text.split()\nfor i in range(len(log_text3)):\n  if log_text3[i]=='s2x2:':\n    chi_squared3.append(float(log_text3[i+1]))\n\nchi_squared4 = []\nlog_text4 = page4.text.split()\nfor i in range(len(log_text4)):\n  if log_text4[i]=='s2x2:':\n    chi_squared4.append(float(log_text4[i+1]))\n    \nchi_squared5 = []\nlog_text5 = page5.text.split()\nfor i in range(len(log_text5)):\n  if log_text5[i]=='s2x2:':\n    chi_squared5.append(float(log_text5[i+1]))\n"

# %%
page2.text
# Out:
# ' rmc.shift.swap.mac\n Fm-3m             225\n Lattice constants :\n    a          b          c         alpha      beta       gamma      volume\n    4.07890    4.07890    4.07890   90.00000   90.00000   90.00000    67.8624    \n\n Metric Tensor     :\n      16.63743      0.00000      0.00000\n       0.00000     16.63743      0.00000\n       0.00000      0.00000     16.63743\n\n Reciprocal Lattice constants :\n    a*         b*         c*        alpha*     beta*      gamma*     volume\n    0.24516    0.24516    0.24516   90.00000   90.00000   90.00000   0.147357E-01\n\n Reciprocal metric tensor     : \n       0.06011     -0.00000     -0.00000\n      -0.00000      0.06011     -0.00000\n      -0.00000     -0.00000      0.06011\n\n Setting PDF calculation to no periodic bound., 3D, exact mode ..\n Read PDF data (r =   0.010 to  50.000 A, 49990 points) ...\n Setting up PDF segment ...\n Extending PDF search distance to  51.1429 A ...\n Current PDF calculation settings : \n   Maximum r [A]              :  51.1429\n   Grid size DR [A]           :   0.0100    (        51142 pts)\n   Radiation                  :   X-Rays    (at   0.0000 A**-1)\n\n   Applied corrections        : \n     Q termination (SINC)     : applied, Qmax =  35.0000 A**-1\n     Instrument resolution    : not applied\n     Periodic boundaries      : not applied\n     4 Pi Rho r correction    :  50.0000 A diameter sphere\n     Weight correction        :   1.00000000\n     Convolution therm. Gauss.: applied\n     Resolution broadening    :   0.0000\n     Quad. correlation fac.   :   0.3000\n     Linear correlation fac.  :   0.0000\n     PDF peak width ratio     :   1.0000 below   0.0000 A\n     Number density           : automatic\n     Correction for RHO0      :   1.0000\n     PDF calculation mode     : all atoms\n\n   Refinement settings        : \n     Fit minimum r [A]        :   0.0100   (pt.    1)\n     Fit maximum r [A]        :  50.0000   (pt. 5000)\n     Current scale factor     :   1.0000   (refined = F)\n\n   Selected atoms for PDF calculation :\n     Atoms (i)                : PD(1)     NI(2)    \n     Atoms (j)                : PD(1)     NI(2)    \n\n   Weights for PDF calculation (internal) :\n     PD(1)     - PD(1)        :      1.5526813    \n     PD(1)     - NI(2)        :     0.94517814    \n     NI(2)     - NI(2)        :     0.57536708    \n\n Current RMC settings (not all used here) :\n   Valid neighbours          : all\n   Calc. scaling/backgr.     : none\n   Fourier volume            : complete crystal\n   Max. number of RMC cycles :    39250\n   Output update intervall   :    39250   (logging to rmc.log=F)\n   SIGMA for CHI calculation :   0.0100\n Minimal allowed distances   : \n     PD(1)     and PD(1)     :   0.500\n     PD(1)     and NI(2)     :   0.500\n     NI(2)     and NI(2)     :   0.500\n\n Sigma for created RMC moves : \n              Atom PD(1)     :   0.200   0.200   0.200\n              Atom NI(2)     :   0.200   0.200   0.200\n\n Selected atoms for RMC      : VOID(0)   PD(1)     NI(2)    \n Setting up PDF segment ...\n Extending PDF search distance to  51.1429 A ...\n Running PDF-Fit ...\n\n Size of model crystal     :   1 x   1 x   1 containing      3925 atoms\n\n Elapsed time    :  0.625000E-01 sec\n\n Starting main RMC loop ...\n (Mode SHIFT) \n\n Gen:    39250 try:    17498 acc: (good/bad):     2241 /      467 s2x2:   18.995891    \n Gen:    78500 try:    35013 acc: (good/bad):     2653 /      650 s2x2:   18.954593    \n\n ---- Final configuration (s=   1.0000) ---- \n\n Gen:    88258 try:    39250 acc: (good/bad):     2713 /      674 s2x2:   18.948744    \n\n Delta Chi    : ave:      0.9881E-03 sig:      0.6180E-03 max:      0.3350E-02\n\n Elapsed time :    0 h 50 min 32 sec \n Time/cycle   :     0.077 sec\n\n Setting up PDF segment ...\n Extending PDF search distance to  51.1429 A ...\n Running PDF-Fit ...\n\n Size of model crystal     :   1 x   1 x   1 containing      3925 atoms\n\n Elapsed time    :  0.468750E-01 sec\n\n S ...

# %%
################################################################################
# Plot Chi_Squared Data
################################################################################
fig1, ax1 = plt.subplots(figsize=(6,4),dpi=200)
ax1.plot(chi_squared1, color='black')
ax1.plot(chi_squared2, color='blue')
ax1.plot(chi_squared3, color='red')
ax1.plot(chi_squared4, color='green')
ax1.plot(chi_squared5, color='orange')

################################################################################
# Plot settings
################################################################################
ax1.set_title(PlotTitle, fontsize=20)
ax1.set_ylabel(r'$\chi^2$', fontsize=16)
ax1.tick_params(axis='y', labelsize=12, direction='in', length=8)
ax1.set_xlabel(r'Cycles', fontsize=16)
ax1.tick_params(axis='x', labelsize=12, direction='in', length=8)
ax1.set_xticklabels([])
ax1.grid(True, linestyle='--')
ax1.set_axisbelow(True)
ax1.set_ylim(0,5)

col_labels=['Run',r'$\chi^2$']
table_vals=[[1, min(chi_squared1)],[2, min(chi_squared2)],[3, min(chi_squared3)],[4, min(chi_squared4)],[5, min(chi_squared5)]]
# the rectangle is where I want to place the table
the_table = plt.table(cellText=table_vals,
                  colWidths = [0.3]*3,
                  colLabels=col_labels,
                  loc='upper right',
                  colLoc = 'center',
                  cellLoc = 'center',
                  zorder=1)

plt.tight_layout()

# %%
fig1.savefig(savename)
files.download(savename)
